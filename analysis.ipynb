# %% [markdown]
# <h1>books.toscrape analysis</h1>
# <p>books.toscrape.com is a web scraping sandbox that allows users to scrape books from their catalogue. despite the data being ficticious, this analysis is meant to demonstrate the different skills that can be performed and conclusions that can be drawn from the data provided. so, for this notebook, we will be treating books.toscrape's data as if it were an early Amazon's equivalent (online book retailer) and exploring what factors contribute to book stockage and rating.</p>

# %% [markdown]
# <h2>setting up</h2>

# %%
#import statements
import pandas as pd
import numpy as np

# %%
#configuring dataframe 
df = pd.read_json('books.json', orient='index').rename_axis('title').reset_index()
df
# Out:
#                                                  title               upc  \
# 0                                 A Light in the Attic  a897fe39b1053632
# 1                                   Tipping the Velvet  90fa61229261140a
# 2                                           Soumission  6957f44c3847a760
# 3                                        Sharp Objects  e00eb4fd7b871a48
# 4                Sapiens: A Brief History of Humankind  4165285e1663650f
# ..                                                 ...               ...
# 994  Alice in Wonderland (Alice's Adventures in Won...  cd2a2a70dd5d176d
# 995   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  bfd5e1701c862ac3
# 996  A Spy's Devotion (The Regency Spies of London #1)  19fec36a1dfb4c16
# 997                1st to Die (Women's Murder Club #1)  f684a82adc49f011
# 998                 1,000 Places to See Before You Die  228ba5e7577e1d49
#
#                category  stars   price availability  stock  \
# 0                poetry      3  £51.77     in stock     22
# 1    historical fiction      1  £53.74     in stock     20
# 2               fiction      1  £50.10     in stock     20
# 3               mystery      4  £47.82     in stock     20
# 4               history      5  £54.23     in stock     20
# ..                  ...    ...     ...          ...    ...
# 994            classics      1  £55.53     in stock      1
# 995      sequential art      4  £57.06     in stock      1
# 996  historical fiction      5  £16.97     in stock      1
# 997             mystery      1  £53.98     in stock      1
# 998              travel      5  £26.08     in stock      1
#
#                                                   href  \
# 0                 a-light-in-the-attic_1000/index.html
# 1                    tipping-the-velvet_999/index.html
# 2                            soumission_998/index.html
# 3                         sharp-objects_997/index.html
# 4    sapiens-a-brief-history-of-humankind_996/index...
# ..                                                 ...
# 994  alice-in-wonderland-alices-adventures-in-wonde...
# 995  ajin-demi-human-volume-1-ajin-demi-human-1_4/i...
# 996  a-spys-devotion-the-regency-spies-of-london-1_...
# 997       1st-to-die-womens-murder-club-1_2/index.html
# 998     1000-places-to-see-before-you-die_1/index.html
#
#                                            description
# 0    It's hard to imagine a world without A Light i...
# 1    "Erotic and absorbing...Written with starling ...
# 2    Dans une France assez proche de la nôtre, un h...
# 3    WICKED above her hipbone, GIRL across her hear...
# 4    From a renowned historian comes a groundbreaki...
# ..                                                 ...
# 994                                               None
# 995  High school student Kei Nagai is struck dead i...
# 996  In England’s Regency era, manners and elegance...
# 997  James Patterson, bestselling author of the Ale...
# 998  Around the World, continent by continent, here...
#
# [999 rows x 9 columns]

# %%
#converting price column to numbers to conduct numerical analysis
df['price'] = df.price.apply(lambda x: x.split('£')[1]).astype(float)

# %% [markdown]
# <h2>exploratory analysis</h2>
# <ul>
# <li>what are the top 5 categories in stock?</li>
# <li>how many books are in each star rating?</li>
# <li>what is the max price? what is the min price?</li>
# </ul>

# %%
#top 5 categories
df.category.value_counts().head(5)
# Out:
# default           152
# nonfiction        110
# sequential art     75
# add a comment      67
# fiction            65
# Name: category, dtype: int64

# %%
#number of 5 star books
df.stars.value_counts()
# Out:
# 1    226
# 3    203
# 2    196
# 5    195
# 4    179
# Name: stars, dtype: int64

# %%
#max price of book
df.price.max()
# Out:
# 59.99

# %%
#min price of book
df.price.min()
# Out:
# 10.0

# %% [markdown]
# <h2>drilling down into highly rated books (4 and 5 star ratings)</h2>
# after taking a quick overview of the data, we want to better understand the characteristics of highly rated books in order to optimize the selection books.toscrape.com has.
# <ul>
# <li>what 5 categories show up the most in 4 and 5 star ratings?</li>
# <li>what is the average price 4 and 5 star ratings?</li>
# <li>what are the 5 most frequently used words of each description (excluding prepositions/connecting words)?</li>
# <li>is there a pattern to the themes discussed in highly rated books?</li>
# </ul>

# %%
#filtering down the data frame to 4 and 5 star ratings
#hrb = highly rated books
hrb = df[(df.stars == 5) | (df.stars == 4)]
hrb
# Out:
#                                                  title               upc  \
# 3                                        Sharp Objects  e00eb4fd7b871a48
# 4                Sapiens: A Brief History of Humankind  4165285e1663650f
# 6    The Dirty Little Secrets of Getting Your Dream...  2597b5a345f45e1b
# 8    The Boys in the Boat: Nine Americans and Their...  e10e1e165dc8be4a
# 11                               Shakespeare's Sonnets  30a7f60cd76ca58c
# ..                                                 ...               ...
# 990                      Bounty (Colorado Mountain #7)  abc0b15f2c907ff0
# 992  Bleach, Vol. 1: Strawberry and the Soul Reaper...  099fae4a0705d63b
# 995   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  bfd5e1701c862ac3
# 996  A Spy's Devotion (The Regency Spies of London #1)  19fec36a1dfb4c16
# 998                 1,000 Places to See Before You Die  228ba5e7577e1d49
#
#                category  stars  price availability  stock  \
# 3               mystery      4  47.82     in stock     20
# 4               history      5  54.23     in stock     20
# 6              business      4  33.34     in stock     19
# 8               default      4  22.60     in stock     19
# 11               poetry      4  20.66     in stock     19
# ..                  ...    ...    ...          ...    ...
# 990             romance      4  37.26     in stock      1
# 992      sequential art      5  34.65     in stock      1
# 995      sequential art      4  57.06     in stock      1
# 996  historical fiction      5  16.97     in stock      1
# 998              travel      5  26.08     in stock      1
#
#                                                   href  \
# 3                         sharp-objects_997/index.html
# 4    sapiens-a-brief-history-of-humankind_996/index...
# 6    the-dirty-little-secrets-of-getting-your-dream...
# 8    the-boys-in-the-boat-nine-americans-and-their-...
# 11                 shakespeares-sonnets_989/index.html
# ..                                                 ...
# 990            bounty-colorado-mountain-7_9/index.html
# 992  bleach-vol-1-strawberry-and-the-soul-reapers-b...
# 995  ajin-demi-human-volume-1-ajin-demi-human-1_4/i...
# 996  a-spys-devotion-the-regency-spies-of-london-1_...
# 998     1000-places-to-see-before-you-die_1/index.html
#
#                                            description
# 3    WICKED above her hipbone, GIRL across her hear...
# 4    From a renowned historian comes a groundbreaki...
# 6    Drawing on his extensive experience evaluating...
# 8    For readers of Laura Hillenbrand's Seabiscuit ...
# 11   This book is an important and complete collect...
# ..                                                 ...
# 990  Justice Lonesome has enjoyed a life of bounty....
# 992  Hot-tempered 15-year-old Ichigo Kurosaki, the ...
# 995  High school student Kei Nagai is struck dead i...
# 996  In England’s Regency era, manners and elegance...
# 998  Around the World, continent by continent, here...
#
# [374 rows x 9 columns]

# %%
#top 5 categories
hrb.category.value_counts().head(5)
# Out:
# default           52
# nonfiction        38
# young adult       30
# sequential art    29
# fiction           27
# Name: category, dtype: int64

# %%
#average price of the dataframe
hrb.price.mean().round(2)
# Out:
# 35.69

# %%
#import nlp library
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
hrb.description[3]
# Out:
# 'WICKED above her hipbone, GIRL across her heart Words are like a road map to reporter Camille Preaker’s troubled past. Fresh from a brief stay at a psych hospital, Camille’s first assignment from the second-rate daily paper where she works brings her reluctantly back to her hometown to cover the murders of two preteen girls. NASTY on her kneecap, BABYDOLL on her leg Since WICKED above her hipbone, GIRL across her heart Words are like a road map to reporter Camille Preaker’s troubled past. Fresh from a brief stay at a psych hospital, Camille’s first assignment from the second-rate daily paper where she works brings her reluctantly back to her hometown to cover the murders of two preteen girls. NASTY on her kneecap, BABYDOLL on her leg Since she left town eight years ago, Camille has hardly spoken to her neurotic, hypochondriac mother or to the half-sister she barely knows: a beautiful thirteen-year-old with an eerie grip on the town. Now, installed again in her family’s Victorian mansion, Camille is haunted by the childhood tragedy she has spent her whole life trying to cut from her memory. HARMFUL on her wrist, WHORE on her ankle As Camille works to uncover the truth about these violent crimes, she finds herself identifying with the young victims—a bit too strongly. Clues keep leading to dead ends, forcing Camille to unravel the psychological puzzle of her own past to get at the story. Dogged by her own demons, Camille will have to confront what happened to her years before if she wants to survive this homecoming.With its taut, crafted writing, Sharp Objects is addictive, haunting, and unforgettable. ...more'

# %%
#tokenize sentences into a list of words - nltk library 
#eliminate the stop words - list comprehension?
#collect the 5 most popular words from each description and save them to a dictionary

# %%
sw = stopwords.words('english')
sw.extend([',','.',':','"','?','*','^','@','!','like','#','1','70,000','6','25','...','’',"'(', 'shapiro', 'author', '1599', ')'","'ve",'‘',"''","'","'t",'11','400','48','23','e.g', 'e.g.',';','``','23','—','“','”',"'re","'s","n't",'227','w','10','12','50','200','xkcd','b','sh','2,000,000','60','34','17','10-25','125','7','5','4','3','2','6,500','53','84','88','40','15','$','45,000','24','--','f','/of','sp','h','11','500','1-4','600','1-5','80','68','13','1,775','109','v-j','109','22','27','6.0','300','13-18','70','71','72','73','74','75','76','77','78','79','1-6','100','1,000','&'])

# %%
#tokenization of descriptions and eliminating stopwords
hrb['words'] = hrb.description.apply(lambda x: x.lower()).apply(lambda x: word_tokenize(x)).apply(lambda x: [word for word in x if not word in sw])
# Out:
# C:\Users\Trish\AppData\Local\Temp\ipykernel_25436\907001476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hrb['words'] = hrb.description.apply(lambda x: x.lower()).apply(lambda x: word_tokenize(x)).apply(lambda x: [word for word in x if not word in sw])

# %%
words_dict = {}
for i in hrb.words:
    for word in i:
        if word not in words_dict.keys():
            words_dict[word] = 1
        else:
            words_dict[word]+=1

# %%
words_dict.keys()
# Out:
# dict_keys(['wicked', 'hipbone', 'girl', 'across', 'heart', 'words', 'road', 'map', 'reporter', 'camille', 'preaker', 'troubled', 'past', 'fresh', 'brief', 'stay', 'psych', 'hospital', 'first', 'assignment', 'second-rate', 'daily', 'paper', 'works', 'brings', 'reluctantly', 'back', 'hometown', 'cover', 'murders', 'two', 'preteen', 'girls', 'nasty', 'kneecap', 'babydoll', 'leg', 'since', 'left', 'town', 'eight', 'years', 'ago', 'hardly', 'spoken', 'neurotic', 'hypochondriac', 'mother', 'half-sister', 'barely', 'knows', 'beautiful', 'thirteen-year-old', 'eerie', 'grip', 'installed', 'family', 'victorian', 'mansion', 'haunted', 'childhood', 'tragedy', 'spent', 'whole', 'life', 'trying', 'cut', 'memory', 'harmful', 'wrist', 'whore', 'ankle', 'uncover', 'truth', 'violent', 'crimes', 'finds', 'identifying', 'young', 'victims—a', 'bit', 'strongly', 'clues', 'keep', 'leading', 'dead', 'ends', 'forcing', 'unravel', 'psychological', 'puzzle', 'get', 'story', 'dogged', 'demons', 'confront', 'happened', 'wants', 'survive', 'homecoming.with', 'taut', 'crafted', 'writing', 'sharp', 'objects', 'addictive', 'haunting', 'unforgettable', 'renowned', 'historian', 'comes', 'groundbreaking', 'narrative', 'humanity', 'creation', 'evolution—a', 'international', 'bestseller—that', 'explores', 'ways', 'biology', 'history', 'defined', 'us', 'enhanced', 'understanding', 'means', 'human.', 'one', 'hundred', 'thousand', 'least', 'six', 'different', 'species', 'humans', 'inhabited', 'earth', 'yet', 'today', 'one—h', 'one—homo', 'sapiens', 'others', 'may', 'happen', 'books', 'pursue', 'either', 'historical', 'biological', 'approach', 'dr.', 'yuval', 'noah', 'harari', 'breaks', 'mold', 'highly', 'original', 'book', 'begins', 'appearance', 'modern', 'cognition', 'examining', 'role', 'evolving', 'played', 'global', 'ecosystem', 'charting', 'rise', 'empires', 'integrates', 'science', 'reconsider', 'accepted', 'narratives', 'connect', 'developments', 'contemporary', 'concerns', 'examine', 'specific', 'events', 'within', 'context', 'larger', 'ideas.dr', 'also', 'compels', 'look', 'ahead', 'last', 'decades', 'begun', 'bend', 'laws', 'natural', 'selection', 'governed', 'four', 'billion', 'acquiring', 'ability', 'design', 'world', 'around', 'want', 'become', 'featuring', 'photographs', 'maps', 'illustrations/diagrams', 'provocative', 'insightful', 'work', 'sure', 'spark', 'debate', 'essential', 'reading', 'aficionados', 'jared', 'diamond', 'james', 'gleick', 'matt', 'ridley', 'robert', 'wright', 'sharon', 'moalem', 'drawing', 'extensive', 'experience', 'evaluating', 'applicants', 'marketing', 'agency', 'stories', 'based', 'real-life', 'situations', 'sample', 'letters', 'resumes', 'straightforward', 'advice', 'raskin', 'dirty', 'little', 'secrets', 'getting', 'dream', 'job', 'offers', 'necessary', 'tools', 'navigating', 'tough', 'market', 'securing', 'job.don', 'owns', 'operates', 'mme', 'advertising', 'new', 'york', 'city', 'twenty-five', 'interviewed', 'hundreds', 'college', 'graduates', 'positions', 'placed', 'strong', 'emphasis', 'entry-level', 'recruitment', 'creative', 'account', 'management', 'traffic', 'production', 'mentored', 'countless', 'students', 'parents', 'best', 'practices', 'search', 'kept', 'exceptionally', 'detailed', 'notes', 'interviews', 'conducted', 'observing', 'good', 'bad', 'ridiculous', 'irreverent', 'treasure', 'trove', 'over-the-top', 'post', 'interview', 'follow-ups', 'received', 'share', 'wisdom', 'insider', 'gathered', 'help', 'first-time', 'seekers', 'find', 'economy.based', 'remarkable', 'expertise', 'provides', 'exclusive', 'insight', 'process', 'lets', 'readers', 'landing', 'job—or', 'one—and', 'finding', 'career', 'success', 'laura', 'hillenbrand', 'seabiscuit', 'unbroken', 'dramatic', 'american', 'rowing', 'team', 'stunned', 'hitler', '1936', 'berlin', 'olympics', 'daniel', 'brown', 'robust', 'tells', 'university', 'washington', 'eight-oar', 'crew', 'epic', 'quest', 'olympic', 'gold', 'medal', 'transformed', 'sport', 'grabbed', ' ...

# %%
max(words_dict,key=words_dict.get)
# Out:
# 'one'
